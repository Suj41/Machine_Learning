# %% [markdown]
# # Read the CSV file from PC

# %%
import pandas as pd
file = pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="latin1")
file
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %% [markdown]
# # to view certain rows

# %%
file1= pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding='utf-8', nrows=15)
file1
# Out:
#     Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0    42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1    22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2    48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3    11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4    22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 5    22254    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 6    21613    IN-2011-30733   1/2/2011  3/2/2011    Second Class    PO-18865
# 7    34662   CA-2011-115161   1/2/2011  3/2/2011     First Class    LC-17050
# 8    44508     AO-2011-1390   1/2/2011  4/2/2011    Second Class     DK-3150
# 9    23688    ID-2011-56493   1/2/2011  3/2/2011    Second Class    SP-20650
# 10   25293    IN-2011-36074   1/2/2011  5/2/2011    Second Class    DK-13150
# ...

# %% [markdown]
# # to view Specific columns based on names

# %%
file2=pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding='utf-8',
                  nrows=10, usecols=["Customer Name","City"])
file2
# Out:
#        Customer Name           City
# 0    Toby Braunhardt    Constantine
# 1        Joseph Holt    Wagga Wagga
# 2      Annie Thurman       Budapest
# 3       Eugene Moren      Stockholm
# 4        Joseph Holt    Wagga Wagga
# 5        Joseph Holt    Wagga Wagga
# 6  Patrick O'Donnell          Dhaka
# 7       Liz Carlisle  Mission Viejo
# 8     David Kendrick         Luanda
# 9   Stephanie Phelps      Yingcheng

# %% [markdown]
# # to view specific of columns based on number

# %%
file3 = pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="latin1", usecols=[0,1,2,3,4,5])
file3
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID
# 0        TB-11280
# 1        JH-15985
# 2          AT-735
# 3        EM-14140
# 4        JH-15985
# ...           ...
# ...

# %% [markdown]
# # to skip rows values
# ### skiprows =[num] - skips single rows
# ### skiprows = num / range(num) - skips range of rows

# %%
file4=pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="utf-8", usecols=[0,1,2,3,4], skiprows=10)
file4
# Out:
#        23688    ID-2011-56493    1/2/2011  3/2/2011    Second Class
# 0      25293    IN-2011-36074    1/2/2011  5/2/2011    Second Class
# 1       8483   US-2011-118892    1/2/2011  6/2/2011  Standard Class
# 2      41445     IR-2011-6550    1/2/2011  6/2/2011  Standard Class
# 3      16727  ES-2011-5268439    1/2/2011  3/2/2011    Second Class
# 4      21615    IN-2011-30733    1/2/2011  3/2/2011    Second Class
# ...      ...              ...         ...       ...             ...
# 51275  32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51276  47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51277   8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51278   6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51279  36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
# [51280 rows x 5 columns]

# %% [markdown]
# # to make index out of column

# %%
file5= pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv",
                   encoding="utf-8", nrows=16, usecols=range(8), index_col="Customer Name")
file5
# Out:
#                    Row ID         Order ID Order Date Ship Date  \
# Customer Name
# Toby Braunhardt     42433     AG-2011-2040   1/1/2011  6/1/2011
# Joseph Holt         22253    IN-2011-47883   1/1/2011  8/1/2011
# Annie Thurman       48883     HU-2011-1220   1/1/2011  5/1/2011
# Eugene Moren        11731  IT-2011-3647632   1/1/2011  5/1/2011
# Joseph Holt         22255    IN-2011-47883   1/1/2011  8/1/2011
# Joseph Holt         22254    IN-2011-47883   1/1/2011  8/1/2011
# Patrick O'Donnell   21613    IN-2011-30733   1/2/2011  3/2/2011
# Liz Carlisle        34662   CA-2011-115161   1/2/2011  3/2/2011
# David Kendrick      44508     AO-2011-1390   1/2/2011  4/2/2011
# Stephanie Phelps    23688    ID-2011-56493   1/2/2011  3/2/2011
# David Kendrick      25293    IN-2011-36074   1/2/2011  5/2/2011
# Dave Hallsten        8483   US-2011-118892   1/2/2011  6/2/2011
# Patrick O'Brill     41445     IR-2011-6550   1/2/2011  6/2/2011
# ...

# %% [markdown]
# # to giving column header

# %%
file6 = pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="utf-8", nrows =20,
                    usecols=range(5), names=['col1','col2','col3','col4','col5'])
file6
# Out:
#       col1             col2        col3       col4            col5
# 0   Row ID         Order ID  Order Date  Ship Date       Ship Mode
# 1    42433     AG-2011-2040    1/1/2011   6/1/2011  Standard Class
# 2    22253    IN-2011-47883    1/1/2011   8/1/2011  Standard Class
# 3    48883     HU-2011-1220    1/1/2011   5/1/2011    Second Class
# 4    11731  IT-2011-3647632    1/1/2011   5/1/2011    Second Class
# 5    22255    IN-2011-47883    1/1/2011   8/1/2011  Standard Class
# 6    22254    IN-2011-47883    1/1/2011   8/1/2011  Standard Class
# 7    21613    IN-2011-30733    1/2/2011   3/2/2011    Second Class
# 8    34662   CA-2011-115161    1/2/2011   3/2/2011     First Class
# 9    44508     AO-2011-1390    1/2/2011   4/2/2011    Second Class
# 10   23688    ID-2011-56493    1/2/2011   3/2/2011    Second Class
# 11   25293    IN-2011-36074    1/2/2011   5/2/2011    Second Class
# 12    8483   US-2011-118892    1/2/2011   6/2/2011  Standard Class
# ...

# %% [markdown]
# # if there is no header suddenly new value of header appears to solve

# %%
file7 = pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="utf-8", nrows =20,
                    usecols=range(5), header=None, prefix ='column')
file7
# Out:
# C:\Users\uSer\AppData\Local\Temp\ipykernel_14400\1356426866.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   file7 = pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="utf-8", nrows =20,
#    column0          column1     column2    column3         column4
# 0   Row ID         Order ID  Order Date  Ship Date       Ship Mode
# 1    42433     AG-2011-2040    1/1/2011   6/1/2011  Standard Class
# 2    22253    IN-2011-47883    1/1/2011   8/1/2011  Standard Class
# 3    48883     HU-2011-1220    1/1/2011   5/1/2011    Second Class
# 4    11731  IT-2011-3647632    1/1/2011   5/1/2011    Second Class
# 5    22255    IN-2011-47883    1/1/2011   8/1/2011  Standard Class
# 6    22254    IN-2011-47883    1/1/2011   8/1/2011  Standard Class
# 7    21613    IN-2011-30733    1/2/2011   3/2/2011    Second Class
# ...

# %% [markdown]
# # to change the data type of the columns

# %%
file8 = pd.read_csv("D:\\MS_ML\\Pandas\\superstore_dataset2011-2015.csv", encoding="utf-8", nrows =20,
                    usecols=range(20), dtype={'Row ID':'float'})
file8
# Out:
#      Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433.0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253.0    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883.0     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731.0  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255.0    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 5   22254.0    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 6   21613.0    IN-2011-30733   1/2/2011  3/2/2011    Second Class    PO-18865
# 7   34662.0   CA-2011-115161   1/2/2011  3/2/2011     First Class    LC-17050
# 8   44508.0     AO-2011-1390   1/2/2011  4/2/2011    Second Class     DK-3150
# 9   23688.0    ID-2011-56493   1/2/2011  3/2/2011    Second Class    SP-20650
# 10  25293.0    IN-2011-36074   1/2/2011  5/2/2011    Second Class    DK-13150
# ...
